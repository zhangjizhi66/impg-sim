// %%
%jsroot on
TFile *ipf = new TFile("../133Ba_152Eu_casing_merge/152Eu_133Ba.root");
TCanvas *c1 = new TCanvas;

// %%
int nentries = 0;
for (int i=200;i<=2400;i++)
    nentries += ge->GetBinContent(i);
cout<<nentries;
// Out:
// 6257646

// %%
ge->Draw();
c1->Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
ge->Fit("gaus","","",120.5,123);
c1->Draw();
// Out:
// <div id="root_plot_2"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
ge->Fit("gaus","","",79.5,82.5);
c1->Draw();
// Out:
// <div id="root_plot_3"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
ge->Fit("gaus","","",354.5,357.5);
c1->Draw();
// Out:
// <div id="root_plot_4"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
ge->Fit("gaus","","",777,780.5);
c1->Draw();
// Out:
// <div id="root_plot_5"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
ge->Fit("gaus","","",962,966);
c1->Draw();
// Out:
// <div id="root_plot_6"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
ge->Fit("gaus","","",1110,1114);
c1->Draw();
// Out:
// <div id="root_plot_7"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
ge->Fit("gaus","","",1406,1410);
c1->Draw();
// Out:
// <div id="root_plot_8"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
c1->Clear();
double e[5] = {355.966,778.866,964.042,1111.99,1407.97};
double sigma[5] = {0.821466,0.950790,0.995647,1.04545,1.08404};
TGraph *gr = new TGraph(5,e,sigma);
gr->Fit("pol2");
gr->Draw("AP*");
c1->Draw();
// Out:
// <div id="root_plot_9"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
TF1 *f1 = (TF1*)gr->GetFunction("pol2");
cout<<setprecision(10);
cout<<"p0 "<<f1->GetParameter(0)<<'\n';
cout<<"p1 "<<f1->GetParameter(1)<<'\n';
cout<<"p2 "<<f1->GetParameter(2)<<'\n';
// Out:
// p0 0.6796061863
// p1 0.000430312065
// p2 -1.000032158e-07
