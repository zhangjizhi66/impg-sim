// %%
TFile *ipf = new TFile("../root/g4raw_t0.root");
TTree *tree = (TTree*)ipf->Get("tree");
TCanvas *c1 = new TCanvas;

// %%
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : Geant4 data                                            *
// *Entries :   102480 : Total =         5514174 bytes  File  Size =    1221241 *
// *        :          : Tree compression factor =   4.53                       *
// ******************************************************************************
// *Br    0 :EDep      : Double_t tree                                          *
// *Entries :   102480 : Total  Size=    1232804 bytes  File Size  =     469330 *
// *Baskets :       25 : Basket Size=      32000 bytes  Compression=   2.56     *
// *............................................................................*
// *Br    1 :VolNamePre : Char_t tree                                           *
// *Entries :   102480 : Total  Size=    1815083 bytes  File Size  =     240790 *
// *Baskets :       43 : Basket Size=      32000 bytes  Compression=   7.40     *
// ...

// %%
tree->Scan("EDep:Egamma:VolNamePre:GlobalTimePre","","colsize=20",35,90);
// Out:
// ********************************************************************************************************
// *    Row   *                 EDep *               Egamma *           VolNamePre *        GlobalTimePre *
// ********************************************************************************************************
// *       90 * 0.022665413141149587 * 0.356012887992641525 *       Ge_3_6_crystal *   748094636370107392 *
// *       91 * 0.090404366196782881 * 0.356012887992641525 *       Ge_3_6_crystal *   748094636370107392 *
// *       92 *                    0 *                   -1 *                world *   190127912802533088 *
// *       93 * 0.000636830000000004 * 0.080997873501320788 *      BGO_3_2_crystal *   190127912802533120 *
// *       94 * 5.55799999999999e-05 * 0.080997873501320788 *      BGO_3_2_crystal *   190127912802533120 *
// *       95 * 1.28800000000000e-05 * 0.080997873501320788 *      BGO_3_2_crystal *   190127912802533120 *
// ...
