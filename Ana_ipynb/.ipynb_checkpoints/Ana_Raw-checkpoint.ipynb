// %%
TFile *ipf = new TFile("../root/g4raw_t0.root");
TTree *tree = (TTree*)ipf->Get("tree");
TCanvas *c1 = new TCanvas;

// %%
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : Geant4 data                                            *
// *Entries :    18211 : Total =         1007629 bytes  File  Size =     207611 *
// *        :          : Tree compression factor =   4.94                       *
// ******************************************************************************
// *Br    0 :EDep      : Double_t tree                                          *
// *Entries :    18211 : Total  Size=     219513 bytes  File Size  =      80319 *
// *Baskets :        4 : Basket Size=      32000 bytes  Compression=   2.39     *
// *............................................................................*
// *Br    1 :VolNamePre : Char_t tree                                           *
// *Entries :    18211 : Total  Size=     348642 bytes  File Size  =      42991 *
// *Baskets :        8 : Basket Size=      32000 bytes  Compression=   7.55     *
// ...

// %%
tree->Scan("EDep:Egamma:VolNamePre:GlobalTimePre","","colsize=20",30,0);
// Out:
// ********************************************************************************************************
// *    Row   *                 EDep *               Egamma *           VolNamePre *        GlobalTimePre *
// ********************************************************************************************************
// *        0 *                    0 *                   -1 *                world *     9458005951275364 *
// *        1 * 0.000114049999999999 * 0.356012887992641525 *       Ge_3_8_crystal *     9458005951275364 *
// *        2 * 5.06299999999998e-05 * 0.004694220727256939 *       Ge_3_6_crystal *     9458005951275364 *
// *        3 * 9.31900000000001e-05 * 0.004694220727256939 *       Ge_3_6_crystal *     9458005951275364 *
// *        4 * 8.63000000000000e-06 * 0.004694220727256939 *       Ge_3_6_crystal *     9458005951275364 *
// *        5 * 1.69099999999999e-05 * 0.004694220727256939 *       Ge_3_6_crystal *     9458005951275364 *
// ...
