// %%
%jsroot on
TFile *ipf1 = new TFile("hg1687.root");
TH1D *hgexp = (TH1D*)ipf1->Get("g1687_2");
TFile *ipf2 = new TFile("histall.root");
TH1D *hallexp = (TH1D*)ipf2->Get("heall");
TFile *ipf3 = new TFile("Zn64Data/g4reso.root");
TTree *tree = (TTree*)ipf3->Get("tree");
TCanvas *c1 = new TCanvas;

// %%
hallexp->SetLineColor(kRed);
hallexp->Scale(0.006);
hallexp->Sumw2(0);
hallexp->Draw();
tree->Draw("ge>>(4000,0,4000)","","same");
c1->Draw();
// Out:
// <div id="root_plot_1"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...

// %%
hgexp->Draw();
c1->Draw();
// Out:
// <div id="root_plot_2"
//      style="width: 696px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
// ...
